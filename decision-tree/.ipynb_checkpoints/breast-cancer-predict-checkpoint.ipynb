# %%
import pickle
import numpy as np

# %%
model = pickle.load(open('breast_cancer_model.pkl','rb'))

# %%
test_input_benign = np.array([[
    12.5, 14.3, 80.5, 480.0, 0.085, 0.09, 0.04, 0.02, 0.16, 0.060,
    0.25, 1.2, 1.7, 20.0, 300.0, 0.095, 0.10, 0.05, 0.03, 0.19,
    0.065, 13.0, 16.0, 85.0, 510.0, 0.10, 0.12, 0.06, 0.03, 0.21
]]).reshape(1,30)

# %%
model.predict(test_input_benign)
# Out:
# C:\Users\hp\miniconda3\envs\my_env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
test_input_malignant = np.array([[
    18.7, 21.5, 120.4, 1080.0, 0.145, 0.22, 0.30, 0.15, 0.35, 0.090,
    0.45, 2.2, 3.5, 35.0, 1200.0, 0.155, 0.25, 0.32, 0.18, 0.42,
    0.110, 20.0, 28.0, 132.0, 1500.0, 0.17, 0.28, 0.35, 0.20, 0.48
]]).reshape(1,30)

# %%
model.predict(test_input_malignant)
# Out:
# C:\Users\hp\miniconda3\envs\my_env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %% [markdown]
# Model is not working properly, where it should predict 1 it is predicting 0, means patients with cancer are coming out clean which is not a good thing.
